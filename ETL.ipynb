# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/reviews.csv"
# Read Purchasing File and store into Pandas data frame
review_data = pd.read_csv(file_to_load,encoding="utf8")
review_data.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
review_clean = review_data.dropna()
review_clean.count()
# Out:
# listing_id       68222
# id               68222
# date             68222
# reviewer_id      68222
# reviewer_name    68222
# comments         68222
# dtype: int64

# %%
#drop comments
review_cln = review_clean.drop(['comments'],axis=1)
#convert to datetime
review_cln["date"]=pd.to_datetime(review_cln["date"])
review_cln
# Out:
#        listing_id        id       date  reviewer_id reviewer_name
# 0         1178162   4724140 2013-05-21      4298113       Olivier
# 1         1178162   4869189 2013-05-29      6452964     Charlotte
# 2         1178162   5003196 2013-06-06      6449554     Sebastian
# 3         1178162   5150351 2013-06-15      2215611        Marine
# 4         1178162   5171140 2013-06-16      6848427        Andrew
# ...           ...       ...        ...          ...           ...
# 68270     7462268  80537457 2016-06-18     22034145       Antonio
# 68271     7462268  83640094 2016-07-03     40052513         Steve
# 68272     7462268  85797088 2016-07-13     77129134          Nick
# 68273     7462268  97264637 2016-08-26     15799803           Vid
# 68274     7462268  98550693 2016-08-31     90128094       Arianna
#
# [68222 rows x 5 columns]

# %%
#groupby listing_id
review_grouped = review_cln.groupby(['listing_id'])
review_grouped.head()
# Out:
#        listing_id        id       date  reviewer_id reviewer_name
# 0         1178162   4724140 2013-05-21      4298113       Olivier
# 1         1178162   4869189 2013-05-29      6452964     Charlotte
# 2         1178162   5003196 2013-06-06      6449554     Sebastian
# 3         1178162   5150351 2013-06-15      2215611        Marine
# 4         1178162   5171140 2013-06-16      6848427        Andrew
# ...           ...       ...        ...          ...           ...
# 68243     7462268  39468374 2015-07-23     13413108        Daniel
# 68244     7462268  39879632 2015-07-26     36144277        Carlos
# 68245     7462268  42736013 2015-08-15     39342838       Krysten
# 68246     7462268  43471157 2015-08-19     37540760            Yi
# 68247     7462268  44007798 2015-08-23     39471312        Daniel
#
# [11363 rows x 5 columns]

# %%
#for fun, lets do some counts
review_count = review_grouped.count()
review_count.sort_values(by=['id'],ascending=False)
# Out:
#              id  date  reviewer_id  reviewer_name
# listing_id
# 66288       402   402          402            402
# 1497879     320   320          320            320
# 414419      312   312          312            312
# 31796       290   290          290            290
# 815639      281   281          281            281
# ...         ...   ...          ...            ...
# 13578911      1     1            1              1
# 1961034       1     1            1              1
# 13565471      1     1            1              1
# 13565466      1     1            1              1
# 13363171      1     1            1              1
#
# [2829 rows x 4 columns]

# %%
# Store  Calendar CSV to DataFrame
calendar_csv = "Resources/calendar.csv"
calendar_df = pd.read_csv(calendar_csv,encoding="utf8")
calendar_df.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
calendar_df.rename(index=str,columns={"date":"date"},inplace=True)
# convert to datetime
calendar_df["date"]=pd.to_datetime(calendar_df["date"])

# %%
# convert to boolean
calendar_df["available"].replace(["t","f"], [True,False], inplace=True)

# %%
# remove dollar sign
calendar_df["price"] = calendar_df["price"].replace({'\$': '', ',': ''}, regex=True)
# convert the price column to numeric values 
calendar_df["price"] = pd.to_numeric(calendar_df["price"])
calendar_df.head()
# Out:
#    listing_id       date  available  price
# 0    12147973 2017-09-05      False    NaN
# 1    12147973 2017-09-04      False    NaN
# 2    12147973 2017-09-03      False    NaN
# 3    12147973 2017-09-02      False    NaN
# 4    12147973 2017-09-01      False    NaN

# %%
listings_file = "Resources/listings.csv"
listings_df = pd.read_csv(listings_file)
listings_df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
#merge listings and calendar
listings_calendar_df = listings_df.merge(calendar_df, left_on='id', right_on='listing_id')

#sanity check
listings_calendar_df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 2  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 3  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 4  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
#
#   last_scraped                        name  \
# 0   2016-09-07  Sunny Bungalow in the City
# 1   2016-09-07  Sunny Bungalow in the City
# 2   2016-09-07  Sunny Bungalow in the City
# 3   2016-09-07  Sunny Bungalow in the City
# 4   2016-09-07  Sunny Bungalow in the City
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Cozy, sunny, family home.  Master bedroom high...
# 2  Cozy, sunny, family home.  Master bedroom high...
# 3  Cozy, sunny, family home.  Master bedroom high...
# 4  Cozy, sunny, family home.  Master bedroom high...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  The house has an open and cozy feel at the sam...
# 2  The house has an open and cozy feel at the sam...
# 3  The house has an open and cozy feel at the sam...
# 4  The house has an open and cozy feel at the sam...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Cozy, sunny, family home.  Master bedroom high...                none
# 2  Cozy, sunny, family home.  Master bedroom high...                none
# 3  Cozy, sunny, family home.  Master bedroom high...                none
# 4  Cozy, sunny, family home.  Master bedroom high...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                f
# 1  Roslindale is quiet, convenient and friendly. ...  ...                f
# 2  Roslindale is quiet, convenient and friendly. ...  ...                f
# 3  Roslindale is quiet, convenient and friendly. ...  ...                f
# 4  Roslindale is quiet, convenient and friendly. ...  ...                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             f
# 3            moderate                             f
# 4            moderate                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month listing_id       date available  price_y
# 0               NaN   12147973 2017-09-05     False      NaN
# 1               NaN   12147973 2017-09-04     False      NaN
# 2               NaN   12147973 2017-09-03     False      NaN
# 3               NaN   12147973 2017-09-02     False      NaN
# 4               NaN   12147973 2017-09-01     False      NaN
#
# [5 rows x 99 columns]

# %%
#choose only the necessary columns
cleaned_df = listings_calendar_df[["id", "listing_url", "name", "price_y", 
                                   "number_of_reviews", "review_scores_rating", 
                                   "date", "available", "summary", "neighbourhood",
                                  "latitude", "longitude", "property_type", "bedrooms",
                                  "beds"]]

#sanity check
cleaned_df.head()
# Out:
#          id                            listing_url  \
# 0  12147973  https://www.airbnb.com/rooms/12147973
# 1  12147973  https://www.airbnb.com/rooms/12147973
# 2  12147973  https://www.airbnb.com/rooms/12147973
# 3  12147973  https://www.airbnb.com/rooms/12147973
# 4  12147973  https://www.airbnb.com/rooms/12147973
#
#                          name  price_y  number_of_reviews  \
# 0  Sunny Bungalow in the City      NaN                  0
# 1  Sunny Bungalow in the City      NaN                  0
# 2  Sunny Bungalow in the City      NaN                  0
# 3  Sunny Bungalow in the City      NaN                  0
# 4  Sunny Bungalow in the City      NaN                  0
#
#    review_scores_rating       date  available  \
# 0                   NaN 2017-09-05      False
# 1                   NaN 2017-09-04      False
# 2                   NaN 2017-09-03      False
# 3                   NaN 2017-09-02      False
# 4                   NaN 2017-09-01      False
#
#                                              summary neighbourhood   latitude  \
# 0  Cozy, sunny, family home.  Master bedroom high...    Roslindale  42.282619
# 1  Cozy, sunny, family home.  Master bedroom high...    Roslindale  42.282619
# 2  Cozy, sunny, family home.  Master bedroom high...    Roslindale  42.282619
# 3  Cozy, sunny, family home.  Master bedroom high...    Roslindale  42.282619
# 4  Cozy, sunny, family home.  Master bedroom high...    Roslindale  42.282619
#
#    longitude property_type  bedrooms  beds
# 0 -71.133068         House       2.0   3.0
# 1 -71.133068         House       2.0   3.0
# 2 -71.133068         House       2.0   3.0
# 3 -71.133068         House       2.0   3.0
# 4 -71.133068         House       2.0   3.0

# %%
#drop na's
dropped_listings_df = cleaned_df.dropna(how='any', axis=0)

#sanity check
dropped_listings_df
# Out:
#                id                            listing_url  \
# 365       3075044   https://www.airbnb.com/rooms/3075044
# 366       3075044   https://www.airbnb.com/rooms/3075044
# 367       3075044   https://www.airbnb.com/rooms/3075044
# 368       3075044   https://www.airbnb.com/rooms/3075044
# 369       3075044   https://www.airbnb.com/rooms/3075044
# ...           ...                                    ...
# 1308518  14603878  https://www.airbnb.com/rooms/14603878
# 1308519  14603878  https://www.airbnb.com/rooms/14603878
# 1308520  14603878  https://www.airbnb.com/rooms/14603878
# 1308521  14603878  https://www.airbnb.com/rooms/14603878
# 1308522  14603878  https://www.airbnb.com/rooms/14603878
#
#                                           name  price_y  number_of_reviews  \
# 365          Charming room in pet friendly apt     65.0                 36
# 366          Charming room in pet friendly apt     65.0                 36
# 367          Charming room in pet friendly apt     65.0                 36
# 368          Charming room in pet friendly apt     75.0                 36
# 369          Charming room in pet friendly apt     75.0                 36
# ...                                        ...      ...                ...
# 1308518  Great Location; Train and Restaurants     59.0                  2
# 1308519  Great Location; Train and Restaurants     59.0                  2
# 1308520  Great Location; Train and Restaurants     59.0                  2
# 1308521  Great Location; Train and Restaurants     59.0                  2
# 1308522  Great Location; Train and Restaurants     59.0                  2
#
#          review_scores_rating       date  available  \
# 365                      94.0 2017-08-22       True
# 366                      94.0 2017-08-21       True
# 367                      94.0 2017-08-20       True
# 368                      94.0 2017-08-19       True
# 369                      94.0 2017-08-18       True
# ...                       ...        ...        ...
# 1308518                  90.0 2016-09-12       True
# 1308519                  90.0 2016-09-11       True
# 1308520                  90.0 2016-09-10       True
# 1308521                  90.0 2016-09-09       True
# 1308522                  90.0 2016-09-08       True
#
#                                                    summary neighbourhood  \
# 365      Charming and quiet room in a second floor 1910...    Roslindale
# 366      Charming and quiet room in a second floor 1910...    Roslindale
# 367      Charming and quiet room in a second floor 1910...    Roslindale
# 368      Charming and quiet room in a second floor 1910...    Roslindale
# 369      Charming and quiet room in a second floor 1910...    Roslindale
# ...                                                    ...           ...
# 1308518  My place is close to Taco Loco Mexican Grill, ...    Somerville
# 1308519  My place is close to Taco Loco Mexican Grill, ...    Somerville
# 1308520  My place is close to Taco Loco Mexican Grill, ...    Somerville
# 1308521  My place is close to Taco Loco Mexican Grill, ...    Somerville
# 1308522  My place is close to Taco Loco Mexican Grill, ...    Somerville
#
#           latitude  longitude property_type  bedrooms  beds
# 365      42.286241 -71.134374     Apartment       1.0   1.0
# 366      42.286241 -71.134374     Apartment       1.0   1.0
# 367      42.286241 -71.134374     Apartment       1.0   1.0
# 368      42.286241 -71.134374     Apartment       1.0   1.0
# 369      42.286241 -71.134374     Apartment       1.0   1.0
# ...            ...        ...           ...       ...   ...
# 1308518  42.385226 -71.080923     Apartment       1.0   1.0
# 1308519  42.385226 -71.080923     Apartment       1.0   1.0
# 1308520  42.385226 -71.080923     Apartment       1.0   1.0
# 1308521  42.385226 -71.080923     Apartment       1.0   1.0
# 1308522  42.385226 -71.080923     Apartment       1.0   1.0
#
# [397694 rows x 15 columns]

# %%
#create database connection
connection = "postgres:postgres@localhost:5432/airbnb_db"
engine = create_engine(f'postgresql://{connection}')

# %%
#table names
engine.table_names()
# Out:
# ['listings', 'reviews']

# %%
#load df into database
dropped_listings_df.to_sql(name='listings', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "summary" of relation "listings" does not exist
# LINE 1: ...f_reviews, review_scores_rating, date, available, summary, n...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-31-f4806a169bf1> in <module>
#       1 #load df into database
# ----> 2 dropped_listings_df.to_sql(name='listings', con=engine, if_exists='append', index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980             raise exc.ObjectNotExecutableError(object_)
#     981         else:
# --> 982             return meth(self, multiparams, params)
#     983
#     984     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1099             distilled_params,
#    1100             compiled_sql,
# -> 1101             distilled_params,
#    1102         )
#    1103         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1224                 if not evt_handled:
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#    1228             elif not parameters and context.no_parameters:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "summary" of relation "listings" does not exist
# LINE 1: ...f_reviews, review_scores_rating, date, available, summary, n...
#                                                              ^
#
# [SQL: INSERT INTO listings (index, id, listing_url, name, price_y, number_of_reviews, review_scores_rating, date, available, summary, neighbourhood, latitude, longitude, property_type, bedrooms, beds) VALUES (%(index)s, %(id)s, %(listing_url)s, %(name)s, %(price_y)s, %(number_of_reviews)s, %(review_scores_rating)s, %(date)s, %(available)s, %(summary)s, %(neighbourhood)s, %(latitude)s, %(longitude)s, %(property_type)s, %(bedrooms)s, %(beds)s)]
# [parameters: ({'index': 365, 'id': 3075044, 'listing_url': 'https://www.airbnb.com/rooms/3075044', 'name': 'Charming room in pet friendly apt', 'price_y': 65.0, 'number_of_reviews': 36, 'review_scores_rating': 94.0, 'date': datetime.datetime(2017, 8, 22, 0, 0), 'available': True, 'summary': "Charming and quiet room in a second floor 1910 condo building. The room has a full size bed, darkening curtains, window A/C unit. It's quiet because it's in the back of the house. Shared bathroom. Guests can use kitchen, living room. Pet friendly.", 'neighbourhood': 'Roslindale', 'latitude': 42.286240821867416, 'longitude': -71.13437396457161, 'property_type': 'Apartment', 'bedrooms': 1.0, 'beds': 1.0}, {'index': 366, 'id': 3075044, 'listing_url': 'https://www.airbnb.com/rooms/3075044', 'name': 'Charming room in pet friendly apt', 'price_y': 65.0, 'number_of_reviews': 36, 'review_scores_rating': 94.0, 'date': datetime.datetime(2017, 8, 21, 0, 0), 'available': True, 'summary': "Charming and quiet room in a second floor 1910 condo building. The room has a full size bed, darkening curtains, window A/C unit. It's quiet because it's in the back of the house. Shared bathroom. Guests can use kitchen, living room. Pet friendly.", 'neighbourhood': 'Roslindale', 'latitude': 42.286240821867416, 'longitude': -71.13437396457161, 'property_type': 'Apartment', 'bedrooms': 1.0, 'beds': 1.0}, {'index': 367, 'id': 3075044, 'listing_url': 'https://www.airbnb.com/rooms/3075044', 'name': 'Charming room in pet friendly apt', 'price_y': 65.0, 'number_of_reviews': 36, 'review_scores_rating': 94.0, 'date': datetime.datetime(2017, 8, 20, 0, 0), 'available': True, 'summary': "Charming and quiet room in a second floor 1910 condo building. The room has a full size bed, darkening curtains, window A/C unit. It's quiet because it's in the back of the house. Shared bathroom. Guests can use kitchen, living room. Pet friendly.", 'neighbourhood': 'Roslindale', 'latitude': 42.286240821867416, 'longitude': -71.13437396457161, 'property_type': 'Apartment', 'bedrooms': 1.0, 'beds': 1.0}, {'index': 368, 'id': 3075044, 'listing_url': 'https://www.airbnb.com/rooms/3075044', 'name': 'Charming room in pet friendly apt', 'price_y': 75.0, 'number_of_reviews': 36, 'review_scores_rating': 94.0, 'date': datetime.datetime(2017, 8, 19, 0, 0), 'available': True, 'summary': "Charming and quiet room in a second floor 1910 condo building. The room has a full size bed, darkening curtains, window A/C unit. It's quiet because it's in the back of the house. Shared bathroom. Guests can use kitchen, living room. Pet friendly.", 'neighbourhood': 'Roslindale', 'latitude': 42.286240821867416, 'longitude': -71.13437396457161, 'property_type': 'Apartment', 'bedrooms': 1.0, 'beds': 1.0}, {'index': 369, 'id': 3075044, 'listing_url': 'https://www.airbnb.com/rooms/3075044', 'name': 'Charming room in pet friendly apt', 'price_y': 75.0, 'number_of_reviews': 36, 'review_scores_rating': 94.0, 'date': datetime.datetime(2017, 8, 18, 0, 0), 'available': True, 'summary': "Charming and quiet room in a second floor 1910 condo building. The room has a full size bed, darkening curtains, window A/C unit. It's quiet because it's in the back of the house. Shared bathroom. Guests can use kitchen, living room. Pet friendly.", 'neighbourhood': 'Roslindale', 'latitude': 42.286240821867416, 'longitude': -71.13437396457161, 'property_type': 'Apartment', 'bedrooms': 1.0, 'beds': 1.0}, {'index': 370, 'id': 3075044, 'listing_url': 'https://www.airbnb.com/rooms/3075044', 'name': 'Charming room in pet friendly apt', 'price_y': 65.0, 'number_of_reviews': 36, 'review_scores_rating': 94.0, 'date': datetime.datetime(2017, 8, 17, 0, 0), 'available': True, 'summary': "Charming and quiet room in a second floor 1910 condo building. The room has a full size bed, darkening curtains, window A/C unit. It's quiet because it's in the back of the house. Shared bathroom. Guests can use kitchen, living room. Pet friendly.", 'neighbourhood': 'Roslindal ...
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
review_count.to_sql(name='reviews', con=engine, if_exists='append', index=True)

# %%
#query results to confirm data has been added
pd.read_sql_query('select * from reviews', con=engine).head()
# Out:
#    listing_id  id  date  reviewer_id  reviewer_name
# 0        3353  34    34           34             34
# 1        5506  36    36           36             36
# 2        6695  47    47           47             47
# 3        6976  41    41           41             41
# 4        8792  18    18           18             18

# %%
pd.read_sql_query('select * from listings', con=engine).head()
# Out:
#      index       id                           listing_url  \
# 0   532900   414419   https://www.airbnb.com/rooms/414419
# 1   247835   815639   https://www.airbnb.com/rooms/815639
# 2   106792  1136972  https://www.airbnb.com/rooms/1136972
# 3  1088699  1584362  https://www.airbnb.com/rooms/1584362
# 4  1032849  1472520  https://www.airbnb.com/rooms/1472520
#
#                                   name  price_y  number_of_reviews  \
# 0   Back Bay! Best Location in Boston!    175.0                312
# 1  MedaevalModernHaven in the NorthEnd    185.0                281
# 2  Boston Room/Free Transit/ By Subway     70.0                280
# 3   Grace's Harborview Fast T Downtown     57.0                232
# 4     Andrea's Private Bath T Downtown     61.0                231
#
#    review_scores_rating       date  available
# 0                  92.0 2017-09-05       True
# 1                  92.0 2017-09-05       True
# 2                  96.0 2016-12-27       True
# 3                  97.0 2017-09-05       True
# 4                  96.0 2017-09-05       True
